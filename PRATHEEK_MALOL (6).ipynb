# %%
from keras.datasets import mnist
data = mnist.load_data()

# %%
((x_train, y_train), (x_test, y_test)) = data

# %%
x_train = x_train.reshape((x_train.shape[0], 28*28)).astype('float32')
x_test = x_test.reshape((x_test.shape[0], 28*28)).astype('float32')

# %%
x_train = x_train / 255
x_test = x_test / 255

# %%
from keras.utils import np_utils
print(y_test.shape)
y_train = np_utils.to_categorical(y_train)
y_test = np_utils.to_categorical(y_test)
num_classes = y_test.shape[1]
print(y_test.shape)
# Out:
# (10000,)
# (10000, 10)

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(32, input_dim = 28*28, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(10, activation='softmax'))

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_39 (Dense)             (None, 32)                25120
# _________________________________________________________________
# dense_40 (Dense)             (None, 64)                2112
# _________________________________________________________________
# dense_41 (Dense)             (None, 10)                650
# =================================================================
# Total params: 27,882
# Trainable params: 27,882
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train, y_train, epochs=10, batch_size=100)
# Out:
# Epoch 1/10
# 600/600 [==============================] - 2s 2ms/step - loss: 0.7559 - accuracy: 0.7866
# Epoch 2/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.2116 - accuracy: 0.9396
# Epoch 3/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1560 - accuracy: 0.9549
# Epoch 4/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1234 - accuracy: 0.9634
# Epoch 5/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1072 - accuracy: 0.9683
# Epoch 6/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0945 - accuracy: 0.9724
# Epoch 7/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0864 - accuracy: 0.9743
# Epoch 8/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0736 - accuracy: 0.9775
# Epoch 9/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0646 - accuracy: 0.9804
# Epoch 10/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0634 - accuracy: 0.9822

# %%
scores = model.evaluate(x_test,y_test)
print(scores)
# Out:
# 313/313 [==============================] - 0s 958us/step - loss: 0.1091 - accuracy: 0.9669
# [0.10909131914377213, 0.9668999910354614]
